# %% [markdown]
# <center><font size='5'>第三次上机实验任务</font></center>

# %% [markdown]
# <center>姓名：_______    &emsp;&emsp;  学号：_______ &emsp;&emsp;   班级：________</center>

# %% [markdown]
# # 循环的基本操作

# %% [markdown]
# ## 记你学号最后一位数字为n, 请用for语句实现阶乘运算：n!，注意0！=1。

# %% [markdown]
# ## 利用repeat语句输出Fibonacci数列的前20个元素。
# Fibonacci数列的通项公式是：
# $$
# F_{n+1}=F_n+F_{n-1},\quad n=2,3,4,\ldots,
# $$
# 其中初值为$F_1=F_n=1$.

# %% [markdown]
# ## 利用repeat以及break和continue遍历向量c(-1,2,-1,4,-3,5,10), 需要满足：当前元素为负值时不做任何处理，当前元素为偶数时输出加1后的结果，当前元素大于4时停止循环。

# %% [markdown]
# ## 利用合适的循环语句生成九九乘法表

# %% [markdown]
# # 自定义函数的基本应用

# %% [markdown]
# ## 自定义一个函数is.odd(x)来判断x是否为奇数，如果是输出“这是一个奇数”，如果不是输出“这不是一个奇数”。并用x=3,x=10进行测试

# %% [markdown]
# ## 自定义一个函数is.odd2(x,upper)实现功能：如果x是一个奇数且小于upper,则输出“这是一个不大的奇数”，否则输出“这是一个足够大的奇数”

# %% [markdown]
# ## 为了增强函数is.odd2(x,upper)的稳健性，需要给函数加上判断是否为x,upper赋值的功能，当x或upper有一个缺失是，输出“参数不全”并退出

# %% [markdown]
# ## 利用is.odd3(...)的形式实现2.2的功能，即不明确指明形参的名称

# %% [markdown]
# ## 编程函数is.even_odd(x,...)实现功能：1.调用2.3中的is.odd2()函数；2.如果x是偶数数输出“x是个偶数”，如果x是一个奇数且小于upper,则输出“这是一个不大的奇数”，否则输出“这是一个足够大的奇数”

# %% [markdown]
# # R语言的高级绘图语句的应用

# %% [markdown]
# # 利用向量x和y绘制点线图，点以*显示，颜色为红色，点放大为默认值的3倍, 线段以虚线展示，线宽设置为2

# %%
x=runif(10,0,10)
y=rnorm(10,mean=0,sd=2)

# %%
# Out:
# plot without title

# %% [markdown]
# ## 想办法将上题中的线改为蓝色

# %%
# Out:
# plot without title

# %% [markdown]
# ## 依据数据df绘制箱线图，第一列为数据，第二列为类别，不同类别着以不同的颜色

# %%
df=data.frame(x=rnorm(100,mean = 1,sd=2),Class=factor(sample(c('a','b'),size=100,replace = TRUE)))

# %%
# Out:
# plot without title

# %% [markdown]
# ## 对df的第一列数据绘制直方图, 条形的个数为10

# %%
# Out:
# Plot with title "Histogram of df$x"

# %% [markdown]
# ## 利用vcd包中的Arthritis$Improved数据绘制水平放置的条形图

# %%
library("vcd")  # 安装vcd包
counts = table(Arthritis$Improved)

# %%
# Out:
# plot without title

# %% [markdown]
# ## 利用gdp绘制饼图，lbls为每个扇形的名称

# %%
gdp = c(20.90, 15.63, 5.13, 3.78, 2.63, 2.59)
lbls = c("US", "China", "Japan", "Germany", "UK", "India")

# %%
# Out:
# plot without title
